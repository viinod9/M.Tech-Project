# %% [markdown]
# # MINLP

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from gekko import GEKKO
from tabulate import tabulate

# %%
# Main function to solve the MINLP pricing optimization problem
def Solve_MINLP(df, WarmStart_delta, WarmStart_d, TotalBudget, RevenueTarget, MarginTarget,
                       MaxDiscount, MinDiscount, MaxSKU, MaxBundles, MaxCons, w3, w4):
    # Initialize GEKKO model with local (offline) solving
    m = GEKKO(remote=False)
    m.options.SOLVER = 1  # Use APOPT solver (good for MINLP problems)
 
    # Compute weights for revenue and margin to be used in objective function
    total_target = RevenueTarget + MarginTarget
    w1 = RevenueTarget / total_target
    w2 = MarginTarget / total_target
 
    # w1 = 5000
    # w2 = 5000
    # Initialize constants
    BigM = 1e6
    n_items = len(df)  # Number of SKUs
 
    # Declare decision variables:
    # Binary selection variable δ_i (1 if selected, 0 otherwise)
    delta = [m.Var(value=WarmStart_delta[i], lb=0, ub=1, integer=True) for i in range(n_items)]
    # Discount variable d_i (fractional discount between 0 and 1)
    d = [m.Var(value=WarmStart_d[i], lb=0, ub=1) for i in range(n_items)]
    # Revenue and margin variables (continuous, ≥ 0)
    r = [m.Var(lb=0) for _ in range(n_items)]
    m_i = [m.Var(lb=0) for _ in range(n_items)]
 
    # Slack variables for deviation from revenue/margin targets
    z_R = m.Var(lb=0)
    z_M = m.Var(lb=0)
 
    # Extract pricing, sales, elasticity, and cost data from dataframe
    P0 = df['Regular_Price'].values
    S0 = df['Total_Sales'].values
    PE = df['Price_Elasticity'].values
    cost = df['unit_cost'].values
 
    # Define constraints and intermediate equations per SKU

    for i in range(n_items):
        # Discounted price formula using binary and discount variables
        P = P0[i] * (1 - delta[i] * d[i])
        # Demand function using own-price elasticity (log-log form)
        S = S0[i] * ((P / P0[i]) ** PE[i])
        # Revenue = Price × Demand
        m.Equation(r[i] == S * P)
        # Margin = Demand × (Price - Cost)
        m.Equation(m_i[i] == S * (P - cost[i]))
 
        # Constraint: Discounted price must fall within allowed min and max bounds
        m.Equation(P >= P0[i] * (1 - MaxDiscount[i]))
        m.Equation(P <= P0[i] * (1 - MinDiscount[i]))


    # Constraints
    m.Equation(m.sum([delta[i] for i in range(n_items)]) <= MaxSKU)
    # m.Equation(m.sum(m_i) >= MarginTarget - z_M)
    # m.Equation(m.sum(r) >= RevenueTarget - z_R)

    m.Equation(m.sum(m_i) >= m.max2(TotalBudget, MarginTarget - z_M))
    #m.Equation(m.sum(m_i) >= TotalBudget)
    # Objective


    # Demand increase term: S/S0 - 1 (percentage demand increase)
    DemandIncrease = m.sum([(S0[i] * ((P0[i] * (1 - delta[i] * d[i])) / P0[i])**PE[i] - S0[i]) for i in range(n_items)])
    obj = w1 * m.sum(r) + w2 * m.sum(m_i) + w5 * DemandIncrease - w3 * z_R - w4 * z_M

    
    #obj = w1 * m.sum(r) + w2 * m.sum(m_i) - w3 * z_R - w4 * z_M
    m.Obj(-obj)
    try:
        m.solve(disp=True)
    except Exception as e:
        print("⚠️ GEKKO failed. Opening model folder for diagnosis...")
        m.open_folder()
        raise e
    return {
        'delta': [d.value[0] for d in delta],
        'd': [dd.value[0] for dd in d],
        'r': [rr.value[0] for rr in r],
        'margin': [mm.value[0] for mm in m_i],
        'z_R': z_R.value[0],
        'z_M': z_M.value[0]
    }


def print_results(results, df):
    delta = results['delta']
    discounts = results['d']
    revenues = results['r']
    margins = results['margin']
    product_names = df['Product_Description'].values
    summary_df = pd.DataFrame({'Product Name ': product_names,'Selected ': ['Selected' if int(d) == 1 else 'Not Selected' for d in delta],'Discount % ': [f"{round(dis * 100, 2)}%" if sel >= 0.5 else "0.0%" for dis, sel in zip(discounts, delta)],'Revenue ': [f"${round(r, 2)}" for r in revenues],'Margin ': [f"${round(m, 2)}" for m in margins]})
    print("\n OPTIMIZATION RESULTS: ITEM-LEVEL OVERVIEW")
    print(tabulate(summary_df, headers='keys', tablefmt='fancy_grid', showindex=False))
    print("\n\033[1;32m Summary Metrics:\033[0m")
    print(f" Total Selected Items: {sum(1 for d in delta if d >= 0.5)}")
    print(f" Total Revenue: \033[1m${round(sum(revenues), 2)}\033[0m")
    print(f" Total Margin: \033[1m${round(sum(margins), 2)}\033[0m")
    # print(f" Revenue Gap (z_R):{results['z_R']:.2f}")
    # print(f" Margin Gap (z_M):{results['z_M']:.2f}")
   

if __name__ == "__main__":
    # Load data (make sure this file exists and has the correct columns)
    df = pd.read_csv('Subset1_BS_S001_loyalonly (1).csv')
 
    # Initialize model inputs
    n = len(df)
    WarmStart_delta = [0] * n           # Start with no items selected
    WarmStart_d = [0.0] * n             # Start with 0% discount across items
    MaxDiscount = [0.35] * n             # Max discount = 30%
    MinDiscount = [0.0] * n            # Min discount = 0%
    MaxSKU = 12                         # Max SKUs allowed to discount
    MaxBundles = 0                      # Bundle logic not implemented yet
    MaxCons = 0                         # Constraint groups not implemented yet
    RevenueTarget = 20e3
    MarginTarget = 10e3
    TotalBudget = 10e3
 
 
    
    # Budget in terms of allowable margin reduction
    #RevenueTarget = 10000              # Minimum revenue desired
    #MarginTarget = 3000                # Minimum margin desired
    w3 = 10000                          # Penalty for not hitting revenue target
    w4 = 10000                           # Penalty for not hitting margin target
    w5 = 10000
    # Run optimization and print results
    results = Solve_MINLP(df, WarmStart_delta, WarmStart_d, TotalBudget, RevenueTarget,
                                  MarginTarget, MaxDiscount, MinDiscount, MaxSKU, MaxBundles,
                                  MaxCons, w3, w4)
    print_results(results, df)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.3
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            6
#    Constants    :            0
#    Variables    :          152
#    Intermediates:            0
#    Connections  :          108
#    Equations    :          105
#    Residuals    :          105
#
#  Number of state variables:            154
#  Number of total equations: -          111
#  Number of slack variables: -           42
#  ---------------------------------------
#  Degrees of freedom       :              1
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.01 NLPi:    5 Dpth:    0 Lvs:    3 Obj: -4.72E+06 Gap:       NaN
# Iter:     2 I: -1 Tm:      0.04 NLPi:   30 Dpth:    1 Lvs:    2 Obj: -4.72E+06 Gap:       NaN
# Iter:     3 I:  0 Tm:      0.00 NLPi:    4 Dpth:    1 Lvs:    4 Obj: -4.72E+06 Gap:       NaN
# Iter:     4 I: -1 Tm:      0.01 NLPi:    7 Dpth:    2 Lvs:    3 Obj: -4.72E+06 Gap:       NaN
# Iter:     5 I: -9 Tm:      0.60 NLPi:  251 Dpth:    2 Lvs:    2 Obj: -4.72E+06 Gap:       NaN
# Iter:     6 I:  0 Tm:      0.00 NLPi:    3 Dpth:    2 Lvs:    3 Obj: -4.51E+06 Gap:       NaN
# Iter:     7 I:  0 Tm:      0.00 NLPi:    3 Dpth:    1 Lvs:    5 Obj: -4.10E+06 Gap:       NaN
# Iter:     8 I:  0 Tm:      0.01 NLPi:    9 Dpth:    3 Lvs:    7 Obj: -4.51E+06 Gap:       NaN
# Iter:     9 I: -9 Tm:      0.28 NLPi:  251 Dpth:    4 Lvs:    6 Obj: -4.51E+06 Gap:       NaN
# Iter:    10 I:  0 Tm:      0.01 NLPi:   10 Dpth:    4 Lvs:    8 Obj: -4.47E+06 Gap:       NaN
# Iter:    11 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:    9 Obj: -4.47E+06 Gap:       NaN
# Iter:    12 I:  0 Tm:      0.00 NLPi:    3 Dpth:    3 Lvs:   10 Obj: -4.47E+06 Gap:       NaN
# Iter:    13 I:  0 Tm:      0.01 NLPi:    9 Dpth:    4 Lvs:   12 Obj: -4.42E+06 Gap:       NaN
# Iter:    14 I:  0 Tm:      0.00 NLPi:    3 Dpth:    4 Lvs:   13 Obj: -4.42E+06 Gap:       NaN
# Iter:    15 I: -9 Tm:      0.28 NLPi:  252 Dpth:    5 Lvs:   12 Obj: -4.47E+06 Gap:       NaN
# Iter:    16 I:  0 Tm:      0.01 NLPi:   10 Dpth:    5 Lvs:   14 Obj: -4.46E+06 Gap:       NaN
# Iter:    17 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   15 Obj: -4.46E+06 Gap:       NaN
# Iter:    18 I:  0 Tm:      0.01 NLPi:    9 Dpth:    5 Lvs:   17 Obj: -4.42E+06 Gap:       NaN
# Iter:    19 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   18 Obj: -4.42E+06 Gap:       NaN
# Iter:    20 I:  0 Tm:      0.01 NLPi:    7 Dpth:    6 Lvs:   20 Obj: -4.46E+06 Gap:       NaN
# Iter:    21 I: -9 Tm:      0.29 NLPi:  253 Dpth:    7 Lvs:   19 Obj: -4.46E+06 Gap:       NaN
# Iter:    22 I:  0 Tm:      0.01 NLPi:    9 Dpth:    7 Lvs:   21 Obj: -4.07E+06 Gap:       NaN
# Iter:    23 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   22 Obj: -4.07E+06 Gap:       NaN
# Iter:    24 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   23 Obj: -4.21E+06 Gap:       NaN
# Iter:    25 I: -9 Tm:      0.29 NLPi:  254 Dpth:    6 Lvs:   22 Obj: -4.46E+06 Gap:       NaN
# Iter:    26 I:  0 Tm:      0.01 NLPi:    9 Dpth:    6 Lvs:   24 Obj: -4.44E+06 Gap:       NaN
# Iter:    27 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   25 Obj: -4.44E+06 Gap:       NaN
# Iter:    28 I: -9 Tm:      0.34 NLPi:  255 Dpth:    7 Lvs:   24 Obj: -4.44E+06 Gap:       NaN
# Iter:    29 I:  0 Tm:      0.01 NLPi:    9 Dpth:    7 Lvs:   26 Obj: -4.51E+06 Gap:       NaN
# Iter:    30 I: -9 Tm:      0.39 NLPi:  256 Dpth:    8 Lvs:   25 Obj: -4.51E+06 Gap:       NaN
# Iter:    31 I:  0 Tm:      0.01 NLPi:   11 Dpth:    8 Lvs:   27 Obj: -4.45E+06 Gap:       NaN
# Iter:    32 I:  0 Tm:      0.00 NLPi:    4 Dpth:    8 Lvs:   28 Obj: -4.45E+06 Gap:       NaN
# Iter:    33 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:   30 Obj: -4.45E+06 Gap:       NaN
# Iter:    34 I: -9 Tm:      0.34 NLPi:  257 Dpth:   10 Lvs:   29 Obj: -4.45E+06 Gap:       NaN
# Iter:    35 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:   31 Obj: -4.35E+06 Gap:       NaN
# Iter:    36 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:   32 Obj: -4.35E+06 Gap:       NaN
# Iter:    37 I:  0 Tm:      0.00 NLPi:    4 Dpth:    9 Lvs:   33 Obj: -4.36E+06 Gap:       NaN
# Iter:    38 I: -9 Tm:      0.34 NLPi:  258 Dpth:    9 Lvs:   32 Obj: -4.45E+06 Gap:       NaN
# Iter:    39 I:  0 Tm:      0.01 NLPi:    9 Dpth:    9 Lvs:   34 Obj: -4.42E+06 Gap:       NaN
# Iter:    40 I:  0 Tm:      0.00 NLPi:    4 Dpth:    9 Lvs:   35 Obj: -4.42E+06 Gap:       NaN
# Iter:    41 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   36 Obj: -3.92E+06 Gap:       NaN
# Iter:    42 I:  0 Tm:      0.01 NLPi:    7 Dpth:    7 Lvs:   38 Obj: -4.44E+06 Gap:       NaN
# Iter:    43 I: -9 Tm:      0.39 NLPi:  259 Dpth:    8 Lvs:   37 Obj: -4.44E+06 Gap:       NaN
# Iter:    44 I:  0 Tm:      0.01 NLPi:    9 Dpth:    8 Lvs:   39 Obj: -4.39E+06 Gap:       NaN
# Iter:    45 I:  0 Tm:      0.00 NLPi:    4 Dpth:    8 Lvs:   40 Obj: -4.39E+06 Gap:       NaN
# Iter:    46 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   41 Obj: -3.85E+06 Gap:       NaN
# Iter:    47 I: -9 Tm:      0.28 NLPi:  260 Dpth:    5 Lvs:   40 Obj: -4.42E+06 Gap:       NaN
# Iter:    48 I:  0 Tm:      0.01 NLPi:    9 Dpth:    5 Lvs:   42 Obj: -4.42E+06 Gap:       NaN
# Iter:    49 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   43 Obj: -4.42E+06 Gap:       NaN
# Iter:    50 I:  0 Tm:      0.01 NLPi:    8 Dpth:    5 Lvs:   45 Obj: -4.38E+06 Gap:       NaN
# Iter:    51 I:  0 Tm:      0.00 NLPi:    3 Dpth:    5 Lvs:   46 Obj: -4.38E+06 Gap:       NaN
# Iter:    52 I: -9 Tm:      0.28 NLPi:  261 Dpth:    6 Lvs:   45 Obj: -4.42E+06 Gap:       NaN
# Iter:    53 I:  0 Tm:      0.01 NLPi:    8 Dpth:    6 Lvs:   47 Obj: -4.40E+06 Gap:       NaN
# Iter:    54 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   48 Obj: -4.40E+06 Gap:       NaN
# Iter:    55 I:  0 Tm:      0.01 NLPi:    9 Dpth:    6 Lvs:   50 Obj: -4.42E+06 Gap:       NaN
# Iter:    56 I: -9 Tm:      0.34 NLPi:  262 Dpth:    7 Lvs:   49 Obj: -4.42E+06 Gap:       NaN
# Iter:    57 I:  0 Tm:      0.01 NLPi:    8 Dpth:    7 Lvs:   51 Obj: -4.36E+06 Gap:       NaN
# Iter:    58 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   52 Obj: -4.36E+06 Gap:       NaN
# Iter:    59 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   53 Obj: -4.37E+06 Gap:       NaN
# Iter:    60 I: -9 Tm:      0.28 NLPi:  263 Dpth:    6 Lvs:   52 Obj: -4.42E+06 Gap:       NaN
# Iter:    61 I:  0 Tm:      0.01 NLPi:    8 Dpth:    6 Lvs:   54 Obj: -4.40E+06 Gap:       NaN
# Iter:    62 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   55 Obj: -4.40E+06 Gap:       NaN
# Iter:    63 I:  0 Tm:      0.01 NLPi:    9 Dpth:    6 Lvs:   57 Obj: -4.42E+06 Gap:       NaN
# Iter:    64 I: -9 Tm:      0.31 NLPi:  264 Dpth:    7 Lvs:   56 Obj: -4.42E+06 Gap:       NaN
# Iter:    65 I:  0 Tm:      0.01 NLPi:    8 Dpth:    7 Lvs:   58 Obj: -4.36E+06 Gap:       NaN
# Iter:    66 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   59 Obj: -4.36E+06 Gap:       NaN
# Iter:    67 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:   60 Obj: -4.37E+06 Gap:       NaN
# Iter:    68 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs:   62 Obj: -4.42E+06 Gap:       NaN
# Iter:    69 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:   63 Obj: -4.26E+06 Gap:       NaN
# Iter:    70 I: -9 Tm:      0.39 NLPi:  265 Dpth:   10 Lvs:   62 Obj: -4.42E+06 Gap:       NaN
# Iter:    71 I:  0 Tm:      0.01 NLPi:   10 Dpth:   10 Lvs:   64 Obj: -4.34E+06 Gap:       NaN
# Iter:    72 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:   65 Obj: -4.35E+06 Gap:       NaN
# Iter:    73 I: -9 Tm:      0.38 NLPi:  266 Dpth:   11 Lvs:   64 Obj: -4.42E+06 Gap:       NaN
# Iter:    74 I: -9 Tm:      0.72 NLPi:  267 Dpth:   11 Lvs:   63 Obj: -4.42E+06 Gap:       NaN
# Iter:    75 I:  0 Tm:      0.00 NLPi:    5 Dpth:   11 Lvs:   64 Obj: -4.06E+06 Gap:       NaN
# Iter:    76 I: -9 Tm:      0.34 NLPi:  268 Dpth:    7 Lvs:   63 Obj: -4.40E+06 Gap:       NaN
# Iter:    77 I:  0 Tm:      0.01 NLPi:   10 Dpth:    7 Lvs:   65 Obj: -4.41E+06 Gap:       NaN
# Iter:    78 I: -9 Tm:      0.31 NLPi:  269 Dpth:    8 Lvs:   64 Obj: -4.41E+06 Gap:       NaN
# Iter:    79 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:   66 Obj: -4.37E+06 Gap:       NaN
# Iter:    80 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:   67 Obj: -4.37E+06 Gap:       NaN
# Iter:    81 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   68 Obj: -4.41E+06 Gap:       NaN
# Iter:    82 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:   70 Obj: -4.32E+06 Gap:       NaN
# Iter:    83 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:   71 Obj: -4.32E+06 Gap:       NaN
# Iter:    84 I:  0 Tm:      0.01 NLPi:    9 Dpth:    7 Lvs:   73 Obj: -4.40E+06 Gap:       NaN
# Iter:    85 I: -9 Tm:      0.31 NLPi:  270 Dpth:    8 Lvs:   72 Obj: -4.40E+06 Gap:       NaN
# Iter:    86 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:   74 Obj: -4.40E+06 Gap:       NaN
# Iter:    87 I: -9 Tm:      0.33 NLPi:  271 Dpth:    9 Lvs:   73 Obj: -4.40E+06 Gap:       NaN
# Iter:    88 I:  0 Tm:      0.01 NLPi:    9 Dpth:    9 Lvs:   75 Obj: -4.29E+06 Gap:       NaN
# Iter:    89 I:  0 Tm:      0.00 NLPi:    4 Dpth:    9 Lvs:   76 Obj: -4.29E+06 Gap:       NaN
# Iter:    90 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:   77 Obj: -4.31E+06 Gap:       NaN
# Iter:    91 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   78 Obj: -4.35E+06 Gap:       NaN
# Iter:    92 I: -9 Tm:      0.34 NLPi:  272 Dpth:    7 Lvs:   77 Obj: -4.40E+06 Gap:       NaN
# Iter:    93 I:  0 Tm:      0.01 NLPi:   10 Dpth:    7 Lvs:   79 Obj: -4.41E+06 Gap:       NaN
# Iter:    94 I: -9 Tm:      0.32 NLPi:  273 Dpth:    8 Lvs:   78 Obj: -4.41E+06 Gap:       NaN
# Iter:    95 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:   80 Obj: -4.37E+06 Gap:       NaN
# Iter:    96 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:   81 Obj: -4.37E+06 Gap:       NaN
# Iter:    97 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   82 Obj: -4.41E+06 Gap:       NaN
# Iter:    98 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:   84 Obj: -3.82E+06 Gap:       NaN
# Iter:    99 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:   85 Obj: -3.82E+06 Gap:       NaN
# Iter:   100 I:  0 Tm:      0.01 NLPi:    8 Dpth:    7 Lvs:   87 Obj: -3.81E+06 Gap:       NaN
# Iter:   101 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:   88 Obj: -3.81E+06 Gap:       NaN
# Iter:   102 I:  0 Tm:      0.01 NLPi:    6 Dpth:    9 Lvs:   90 Obj: -4.39E+06 Gap:       NaN
# Iter:   103 I:  0 Tm:      0.00 NLPi:    4 Dpth:    9 Lvs:   91 Obj: -4.30E+06 Gap:       NaN
# Iter:   104 I: -9 Tm:      0.43 NLPi:  274 Dpth:    9 Lvs:   90 Obj: -4.39E+06 Gap:       NaN
# Iter:   105 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:   92 Obj: -4.44E+06 Gap:       NaN
# Iter:   106 I: -9 Tm:      0.37 NLPi:  275 Dpth:   10 Lvs:   91 Obj: -4.44E+06 Gap:       NaN
# Iter:   107 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:   93 Obj: -4.44E+06 Gap:       NaN
# Iter:   108 I: -9 Tm:      0.45 NLPi:  276 Dpth:   11 Lvs:   92 Obj: -4.44E+06 Gap:       NaN
# Iter:   109 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:   94 Obj: -4.38E+06 Gap:       NaN
# Iter:   110 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:   95 Obj: -4.29E+06 Gap:       NaN
# Iter:   111 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:   96 Obj: -4.31E+06 Gap:       NaN
# Iter:   112 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:   97 Obj: -4.35E+06 Gap:       NaN
# Iter:   113 I: -9 Tm:      0.37 NLPi:  277 Dpth:   10 Lvs:   96 Obj: -4.39E+06 Gap:       NaN
# Iter:   114 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs:   98 Obj: -4.39E+06 Gap:       NaN
# Iter:   115 I: -9 Tm:      0.39 NLPi:  278 Dpth:   11 Lvs:   97 Obj: -4.39E+06 Gap:       NaN
# Iter:   116 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:   99 Obj: -4.39E+06 Gap:       NaN
# Iter:   117 I: -9 Tm:      0.36 NLPi:  279 Dpth:   12 Lvs:   98 Obj: -4.39E+06 Gap:       NaN
# Iter:   118 I:  0 Tm:      0.01 NLPi:    6 Dpth:   12 Lvs:  100 Obj: -4.39E+06 Gap:       NaN
# Iter:   119 I: -9 Tm:      0.40 NLPi:  280 Dpth:   13 Lvs:   99 Obj: -4.39E+06 Gap:       NaN
# Iter:   120 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  101 Obj: -4.09E+06 Gap:       NaN
# Iter:   121 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  102 Obj: -4.27E+06 Gap:       NaN
# Iter:   122 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  103 Obj: -4.26E+06 Gap:       NaN
# Iter:   123 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  104 Obj: -4.28E+06 Gap:       NaN
# Iter:   124 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  105 Obj: -4.29E+06 Gap:       NaN
# Iter:   125 I: -9 Tm:      0.40 NLPi:  281 Dpth:   12 Lvs:  104 Obj: -4.38E+06 Gap:       NaN
# Iter:   126 I: -9 Tm:      0.72 NLPi:  282 Dpth:   12 Lvs:  103 Obj: -4.38E+06 Gap:       NaN
# Iter:   127 I:  0 Tm:      0.00 NLPi:    6 Dpth:   12 Lvs:  104 Obj: -4.07E+06 Gap:       NaN
# Iter:   128 I: -9 Tm:      0.30 NLPi:  283 Dpth:    6 Lvs:  103 Obj: -4.38E+06 Gap:       NaN
# Iter:   129 I:  0 Tm:      0.01 NLPi:    8 Dpth:    6 Lvs:  105 Obj: -4.36E+06 Gap:       NaN
# Iter:   130 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:  106 Obj: -4.36E+06 Gap:       NaN
# Iter:   131 I:  0 Tm:      0.01 NLPi:    7 Dpth:    6 Lvs:  108 Obj: -4.32E+06 Gap:       NaN
# Iter:   132 I:  0 Tm:      0.00 NLPi:    3 Dpth:    6 Lvs:  109 Obj: -4.32E+06 Gap:       NaN
# Iter:   133 I: -9 Tm:      0.38 NLPi:  284 Dpth:    9 Lvs:  108 Obj: -4.37E+06 Gap:       NaN
# Iter:   134 I:  0 Tm:      0.01 NLPi:    9 Dpth:    9 Lvs:  110 Obj: -4.31E+06 Gap:       NaN
# Iter:   135 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  111 Obj: -4.31E+06 Gap:       NaN
# Iter:   136 I:  0 Tm:      0.01 NLPi:    6 Dpth:    9 Lvs:  113 Obj: -4.37E+06 Gap:       NaN
# Iter:   137 I: -9 Tm:      0.40 NLPi:  285 Dpth:   10 Lvs:  112 Obj: -4.37E+06 Gap:       NaN
# Iter:   138 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  114 Obj: -4.37E+06 Gap:       NaN
# Iter:   139 I: -9 Tm:      0.40 NLPi:  286 Dpth:   11 Lvs:  113 Obj: -4.37E+06 Gap:       NaN
# Iter:   140 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  115 Obj: -4.37E+06 Gap:       NaN
# Iter:   141 I: -9 Tm:      0.44 NLPi:  287 Dpth:   12 Lvs:  114 Obj: -4.37E+06 Gap:       NaN
# Iter:   142 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  116 Obj: -4.27E+06 Gap:       NaN
# Iter:   143 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  117 Obj: -4.27E+06 Gap:       NaN
# Iter:   144 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  118 Obj: -4.02E+06 Gap:       NaN
# Iter:   145 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  119 Obj: -4.22E+06 Gap:       NaN
# Iter:   146 I:  0 Tm:      0.00 NLPi:    4 Dpth:    9 Lvs:  120 Obj: -4.27E+06 Gap:       NaN
# Iter:   147 I: -9 Tm:      0.38 NLPi:  288 Dpth:    9 Lvs:  119 Obj: -4.37E+06 Gap:       NaN
# Iter:   148 I:  0 Tm:      0.01 NLPi:    8 Dpth:    9 Lvs:  121 Obj: -4.44E+06 Gap:       NaN
# Iter:   149 I: -9 Tm:      0.43 NLPi:  289 Dpth:   10 Lvs:  120 Obj: -4.44E+06 Gap:       NaN
# Iter:   150 I:  0 Tm:      0.01 NLPi:    8 Dpth:   10 Lvs:  122 Obj: -4.36E+06 Gap:       NaN
# Iter:   151 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  123 Obj: -4.36E+06 Gap:       NaN
# Iter:   152 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  124 Obj: -3.88E+06 Gap:       NaN
# Iter:   153 I:  0 Tm:      0.01 NLPi:    6 Dpth:    9 Lvs:  126 Obj: -4.37E+06 Gap:       NaN
# Iter:   154 I: -9 Tm:      0.37 NLPi:  290 Dpth:   10 Lvs:  125 Obj: -4.37E+06 Gap:       NaN
# Iter:   155 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs:  127 Obj: -4.37E+06 Gap:       NaN
# Iter:   156 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  128 Obj: -4.27E+06 Gap:       NaN
# Iter:   157 I: -9 Tm:      0.45 NLPi:  291 Dpth:   11 Lvs:  127 Obj: -4.37E+06 Gap:       NaN
# Iter:   158 I:  0 Tm:      0.01 NLPi:    6 Dpth:   11 Lvs:  129 Obj: -4.37E+06 Gap:       NaN
# Iter:   159 I: -9 Tm:      0.36 NLPi:  292 Dpth:   12 Lvs:  128 Obj: -4.37E+06 Gap:       NaN
# Iter:   160 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  130 Obj: -4.37E+06 Gap:       NaN
# Iter:   161 I:  0 Tm:      0.01 NLPi:    4 Dpth:   12 Lvs:  131 Obj: -4.25E+06 Gap:       NaN
# Iter:   162 I: -9 Tm:      0.28 NLPi:  293 Dpth:   13 Lvs:  130 Obj: -4.37E+06 Gap:       NaN
# Iter:   163 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  132 Obj: -4.18E+06 Gap:       NaN
# Iter:   164 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  133 Obj: -4.27E+06 Gap:       NaN
# Iter:   165 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  134 Obj: -4.12E+06 Gap:       NaN
# Iter:   166 I:  0 Tm:      0.00 NLPi:    4 Dpth:    9 Lvs:  135 Obj: -3.79E+06 Gap:       NaN
# Iter:   167 I:  0 Tm:      0.01 NLPi:    7 Dpth:    7 Lvs:  137 Obj: -4.37E+06 Gap:       NaN
# Iter:   168 I: -9 Tm:      0.33 NLPi:  294 Dpth:    8 Lvs:  136 Obj: -4.37E+06 Gap:       NaN
# Iter:   169 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  138 Obj: -4.37E+06 Gap:       NaN
# Iter:   170 I: -9 Tm:      0.35 NLPi:  295 Dpth:    9 Lvs:  137 Obj: -4.37E+06 Gap:       NaN
# Iter:   171 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  139 Obj: -4.37E+06 Gap:       NaN
# Iter:   172 I: -9 Tm:      0.38 NLPi:  296 Dpth:   10 Lvs:  138 Obj: -4.37E+06 Gap:       NaN
# Iter:   173 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  140 Obj: -4.37E+06 Gap:       NaN
# Iter:   174 I: -9 Tm:      0.73 NLPi:  297 Dpth:   11 Lvs:  139 Obj: -4.37E+06 Gap:       NaN
# Iter:   175 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  141 Obj: -4.37E+06 Gap:       NaN
# Iter:   176 I: -9 Tm:      0.64 NLPi:  298 Dpth:   12 Lvs:  140 Obj: -4.37E+06 Gap:       NaN
# Iter:   177 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  142 Obj: -4.26E+06 Gap:       NaN
# Iter:   178 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  143 Obj: -4.26E+06 Gap:       NaN
# Iter:   179 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  144 Obj: -4.24E+06 Gap:       NaN
# Iter:   180 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  145 Obj: -4.21E+06 Gap:       NaN
# Iter:   181 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  146 Obj: -4.27E+06 Gap:       NaN
# Iter:   182 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  147 Obj: -4.28E+06 Gap:       NaN
# Iter:   183 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:  148 Obj: -4.31E+06 Gap:       NaN
# Iter:   184 I:  0 Tm:      0.01 NLPi:    7 Dpth:    7 Lvs:  150 Obj: -4.31E+06 Gap:       NaN
# Iter:   185 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:  151 Obj: -4.31E+06 Gap:       NaN
# Iter:   186 I: -9 Tm:      0.40 NLPi:  299 Dpth:   11 Lvs:  150 Obj: -4.36E+06 Gap:       NaN
# Iter:   187 I:  0 Tm:      0.01 NLPi:    8 Dpth:   11 Lvs:  152 Obj: -4.40E+06 Gap:       NaN
# Iter:   188 I: -9 Tm:      0.44 NLPi:  300 Dpth:   12 Lvs:  151 Obj: -4.40E+06 Gap:       NaN
# Iter:   189 I: -9 Tm:      0.77 NLPi:  301 Dpth:   12 Lvs:  150 Obj: -4.40E+06 Gap:       NaN
# Iter:   190 I:  0 Tm:      0.00 NLPi:    5 Dpth:   12 Lvs:  151 Obj: -4.33E+06 Gap:       NaN
# Iter:   191 I:  0 Tm:      0.00 NLPi:    5 Dpth:   11 Lvs:  152 Obj: -4.31E+06 Gap:       NaN
# Iter:   192 I:  0 Tm:      0.01 NLPi:    8 Dpth:   11 Lvs:  154 Obj: -4.36E+06 Gap:       NaN
# Iter:   193 I: -9 Tm:      0.47 NLPi:  302 Dpth:   12 Lvs:  153 Obj: -4.36E+06 Gap:       NaN
# Iter:   194 I: -9 Tm:      0.90 NLPi:  303 Dpth:   12 Lvs:  152 Obj: -4.36E+06 Gap:       NaN
# Iter:   195 I:  0 Tm:      0.00 NLPi:    5 Dpth:   12 Lvs:  153 Obj: -3.97E+06 Gap:       NaN
# Iter:   196 I:  0 Tm:      0.01 NLPi:    6 Dpth:   11 Lvs:  154 Obj: -4.26E+06 Gap:       NaN
# Iter:   197 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs:  156 Obj: -4.36E+06 Gap:       NaN
# Iter:   198 I: -9 Tm:      0.48 NLPi:  304 Dpth:   11 Lvs:  155 Obj: -4.36E+06 Gap:       NaN
# Iter:   199 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  157 Obj: -4.36E+06 Gap:       NaN
# Iter:   200 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  158 Obj: -4.26E+06 Gap:       NaN
# Iter:   201 I: -9 Tm:      0.46 NLPi:  305 Dpth:   12 Lvs:  157 Obj: -4.36E+06 Gap:       NaN
# Iter:   202 I:  0 Tm:      0.01 NLPi:    6 Dpth:   12 Lvs:  159 Obj: -4.36E+06 Gap:       NaN
# Iter:   203 I: -9 Tm:      0.47 NLPi:  306 Dpth:   13 Lvs:  158 Obj: -4.36E+06 Gap:       NaN
# Iter:   204 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  160 Obj: -4.06E+06 Gap:       NaN
# Iter:   205 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  161 Obj: -4.24E+06 Gap:       NaN
# Iter:   206 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  162 Obj: -4.23E+06 Gap:       NaN
# Iter:   207 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  163 Obj: -4.26E+06 Gap:       NaN
# Iter:   208 I: -9 Tm:      0.34 NLPi:  307 Dpth:    7 Lvs:  162 Obj: -4.36E+06 Gap:       NaN
# Iter:   209 I:  0 Tm:      0.01 NLPi:    9 Dpth:    7 Lvs:  164 Obj: -4.37E+06 Gap:       NaN
# Iter:   210 I: -9 Tm:      0.34 NLPi:  308 Dpth:    8 Lvs:  163 Obj: -4.37E+06 Gap:       NaN
# Iter:   211 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:  165 Obj: -4.33E+06 Gap:       NaN
# Iter:   212 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  166 Obj: -4.33E+06 Gap:       NaN
# Iter:   213 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:  167 Obj: -4.37E+06 Gap:       NaN
# Iter:   214 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:  169 Obj: -4.01E+06 Gap:       NaN
# Iter:   215 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  170 Obj: -4.01E+06 Gap:       NaN
# Iter:   216 I:  0 Tm:      0.01 NLPi:    8 Dpth:    7 Lvs:  172 Obj: -4.36E+06 Gap:       NaN
# Iter:   217 I: -9 Tm:      0.42 NLPi:  309 Dpth:    8 Lvs:  171 Obj: -4.36E+06 Gap:       NaN
# Iter:   218 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  173 Obj: -4.27E+06 Gap:       NaN
# Iter:   219 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  174 Obj: -4.27E+06 Gap:       NaN
# Iter:   220 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:  175 Obj: -4.31E+06 Gap:       NaN
# Iter:   221 I: -9 Tm:      0.36 NLPi:  310 Dpth:    8 Lvs:  174 Obj: -4.36E+06 Gap:       NaN
# Iter:   222 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:  176 Obj: -4.33E+06 Gap:       NaN
# Iter:   223 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  177 Obj: -4.33E+06 Gap:       NaN
# Iter:   224 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:  179 Obj: -3.96E+06 Gap:       NaN
# Iter:   225 I:  0 Tm:      0.01 NLPi:    3 Dpth:    8 Lvs:  180 Obj: -3.96E+06 Gap:       NaN
# Iter:   226 I: -9 Tm:      0.41 NLPi:  311 Dpth:    8 Lvs:  179 Obj: -4.36E+06 Gap:       NaN
# Iter:   227 I:  0 Tm:      0.01 NLPi:    8 Dpth:    8 Lvs:  181 Obj: -4.33E+06 Gap:       NaN
# Iter:   228 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  182 Obj: -4.33E+06 Gap:       NaN
# Iter:   229 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  184 Obj: -4.27E+06 Gap:       NaN
# Iter:   230 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  185 Obj: -4.27E+06 Gap:       NaN
# Iter:   231 I: -9 Tm:      0.48 NLPi:  312 Dpth:   11 Lvs:  184 Obj: -4.35E+06 Gap:       NaN
# Iter:   232 I:  0 Tm:      0.01 NLPi:    8 Dpth:   11 Lvs:  186 Obj: -4.38E+06 Gap:       NaN
# Iter:   233 I: -9 Tm:      0.47 NLPi:  313 Dpth:   12 Lvs:  185 Obj: -4.38E+06 Gap:       NaN
# Iter:   234 I: -9 Tm:      0.77 NLPi:  314 Dpth:   12 Lvs:  184 Obj: -4.38E+06 Gap:       NaN
# Iter:   235 I:  0 Tm:      0.00 NLPi:    6 Dpth:   12 Lvs:  185 Obj: -4.20E+06 Gap:       NaN
# Iter:   236 I:  0 Tm:      0.00 NLPi:    5 Dpth:   11 Lvs:  186 Obj: -4.35E+06 Gap:       NaN
# Iter:   237 I:  0 Tm:      0.01 NLPi:    6 Dpth:   11 Lvs:  188 Obj: -4.35E+06 Gap:       NaN
# Iter:   238 I: -9 Tm:      0.48 NLPi:  315 Dpth:   12 Lvs:  187 Obj: -4.35E+06 Gap:       NaN
# Iter:   239 I: -9 Tm:      0.88 NLPi:  316 Dpth:   12 Lvs:  186 Obj: -4.35E+06 Gap:       NaN
# Iter:   240 I:  0 Tm:      0.00 NLPi:    5 Dpth:   12 Lvs:  187 Obj: -4.22E+06 Gap:       NaN
# Iter:   241 I:  0 Tm:      0.00 NLPi:    5 Dpth:   11 Lvs:  188 Obj: -4.25E+06 Gap:       NaN
# Iter:   242 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  190 Obj: -4.35E+06 Gap:       NaN
# Iter:   243 I: -9 Tm:      0.43 NLPi:  317 Dpth:   11 Lvs:  189 Obj: -4.35E+06 Gap:       NaN
# Iter:   244 I:  0 Tm:      0.01 NLPi:    6 Dpth:   11 Lvs:  191 Obj: -4.35E+06 Gap:       NaN
# Iter:   245 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  192 Obj: -4.22E+06 Gap:       NaN
# Iter:   246 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  193 Obj: -4.19E+06 Gap:       NaN
# Iter:   247 I: -9 Tm:      0.47 NLPi:  318 Dpth:   12 Lvs:  192 Obj: -4.35E+06 Gap:       NaN
# Iter:   248 I: -9 Tm:      0.88 NLPi:  319 Dpth:   12 Lvs:  191 Obj: -4.35E+06 Gap:       NaN
# Iter:   249 I:  0 Tm:      0.00 NLPi:    5 Dpth:   12 Lvs:  192 Obj: -3.96E+06 Gap:       NaN
# Iter:   250 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  194 Obj: -4.35E+06 Gap:       NaN
# Iter:   251 I: -9 Tm:      0.37 NLPi:  320 Dpth:    9 Lvs:  193 Obj: -4.35E+06 Gap:       NaN
# Iter:   252 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  195 Obj: -4.25E+06 Gap:       NaN
# Iter:   253 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  196 Obj: -4.25E+06 Gap:       NaN
# Iter:   254 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  197 Obj: -4.26E+06 Gap:       NaN
# Iter:   255 I:  0 Tm:      0.01 NLPi:    6 Dpth:   11 Lvs:  199 Obj: -4.29E+06 Gap:       NaN
# Iter:   256 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  200 Obj: -4.22E+06 Gap:       NaN
# Iter:   257 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  202 Obj: -4.35E+06 Gap:       NaN
# Iter:   258 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  203 Obj: -4.22E+06 Gap:       NaN
# Iter:   259 I: -9 Tm:      0.43 NLPi:  321 Dpth:   13 Lvs:  202 Obj: -4.35E+06 Gap:       NaN
# Iter:   260 I: -9 Tm:      0.81 NLPi:  322 Dpth:   13 Lvs:  201 Obj: -4.35E+06 Gap:       NaN
# Iter:   261 I:  0 Tm:      0.00 NLPi:    5 Dpth:   13 Lvs:  202 Obj: -3.98E+06 Gap:       NaN
# Iter:   262 I: -9 Tm:      0.48 NLPi:  323 Dpth:   11 Lvs:  201 Obj: -4.34E+06 Gap:       NaN
# Iter:   263 I: -9 Tm:      0.83 NLPi:  324 Dpth:   11 Lvs:  200 Obj: -4.34E+06 Gap:       NaN
# Iter:   264 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs:  201 Obj: -4.09E+06 Gap:       NaN
# Iter:   265 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  203 Obj: -4.12E+06 Gap:       NaN
# Iter:   266 I:  0 Tm:      0.00 NLPi:    5 Dpth:   13 Lvs:  204 Obj: -4.21E+06 Gap:       NaN
# Iter:   267 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  206 Obj: -4.33E+06 Gap:       NaN
# Iter:   268 I: -9 Tm:      0.40 NLPi:  325 Dpth:   10 Lvs:  205 Obj: -4.33E+06 Gap:       NaN
# Iter:   269 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  207 Obj: -4.33E+06 Gap:       NaN
# Iter:   270 I: -9 Tm:      0.43 NLPi:  326 Dpth:   11 Lvs:  206 Obj: -4.33E+06 Gap:       NaN
# Iter:   271 I:  0 Tm:      0.01 NLPi:    8 Dpth:   11 Lvs:  208 Obj: -4.23E+06 Gap:       NaN
# Iter:   272 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  209 Obj: -4.23E+06 Gap:       NaN
# Iter:   273 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  210 Obj: -4.18E+06 Gap:       NaN
# Iter:   274 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  211 Obj: -4.23E+06 Gap:       NaN
# Iter:   275 I: -9 Tm:      0.42 NLPi:  327 Dpth:    9 Lvs:  210 Obj: -4.33E+06 Gap:       NaN
# Iter:   276 I:  0 Tm:      0.01 NLPi:    8 Dpth:    9 Lvs:  212 Obj: -4.32E+06 Gap:       NaN
# Iter:   277 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  213 Obj: -4.32E+06 Gap:       NaN
# Iter:   278 I: -9 Tm:      0.39 NLPi:  328 Dpth:    9 Lvs:  212 Obj: -4.33E+06 Gap:       NaN
# Iter:   279 I:  0 Tm:      0.01 NLPi:    8 Dpth:    9 Lvs:  214 Obj: -4.26E+06 Gap:       NaN
# Iter:   280 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  215 Obj: -4.26E+06 Gap:       NaN
# Iter:   281 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  217 Obj: -4.33E+06 Gap:       NaN
# Iter:   282 I: -9 Tm:      0.38 NLPi:  329 Dpth:   10 Lvs:  216 Obj: -4.33E+06 Gap:       NaN
# Iter:   283 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  218 Obj: -4.33E+06 Gap:       NaN
# Iter:   284 I: -9 Tm:      0.45 NLPi:  330 Dpth:   11 Lvs:  217 Obj: -4.33E+06 Gap:       NaN
# Iter:   285 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  219 Obj: -4.33E+06 Gap:       NaN
# Iter:   286 I: -9 Tm:      0.46 NLPi:  331 Dpth:   12 Lvs:  218 Obj: -4.33E+06 Gap:       NaN
# Iter:   287 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  220 Obj: -4.33E+06 Gap:       NaN
# Iter:   288 I: -9 Tm:      0.39 NLPi:  332 Dpth:   13 Lvs:  219 Obj: -4.33E+06 Gap:       NaN
# Iter:   289 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  221 Obj: -4.33E+06 Gap:       NaN
# Iter:   290 I: -9 Tm:      0.36 NLPi:  333 Dpth:   14 Lvs:  220 Obj: -4.33E+06 Gap:       NaN
# Iter:   291 I:  0 Tm:      0.01 NLPi:    9 Dpth:   14 Lvs:  222 Obj: -4.28E+06 Gap:       NaN
# Iter:   292 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs:  223 Obj: -4.20E+06 Gap:       NaN
# Iter:   293 I:  0 Tm:      0.00 NLPi:    5 Dpth:   13 Lvs:  224 Obj: -4.22E+06 Gap:       NaN
# Iter:   294 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  225 Obj: -4.23E+06 Gap:       NaN
# Iter:   295 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  226 Obj: -3.74E+06 Gap:       NaN
# Iter:   296 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  227 Obj: -4.17E+06 Gap:       NaN
# Iter:   297 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  228 Obj: -3.94E+06 Gap:       NaN
# Iter:   298 I: -9 Tm:      0.39 NLPi:  334 Dpth:    9 Lvs:  227 Obj: -4.33E+06 Gap:       NaN
# Iter:   299 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  229 Obj: -4.42E+06 Gap:       NaN
# Iter:   300 I: -9 Tm:      0.47 NLPi:  335 Dpth:   10 Lvs:  228 Obj: -4.42E+06 Gap:       NaN
# Iter:   301 I:  0 Tm:      0.01 NLPi:    8 Dpth:   10 Lvs:  230 Obj: -4.32E+06 Gap:       NaN
# Iter:   302 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  231 Obj: -4.32E+06 Gap:       NaN
# Iter:   303 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  232 Obj: -3.83E+06 Gap:       NaN
# Iter:   304 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  234 Obj: -4.33E+06 Gap:       NaN
# Iter:   305 I: -9 Tm:      0.41 NLPi:  336 Dpth:   10 Lvs:  233 Obj: -4.33E+06 Gap:       NaN
# Iter:   306 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  235 Obj: -4.33E+06 Gap:       NaN
# Iter:   307 I: -9 Tm:      0.44 NLPi:  337 Dpth:   11 Lvs:  234 Obj: -4.33E+06 Gap:       NaN
# Iter:   308 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  236 Obj: -4.33E+06 Gap:       NaN
# Iter:   309 I: -9 Tm:      0.44 NLPi:  338 Dpth:   12 Lvs:  235 Obj: -4.33E+06 Gap:       NaN
# Iter:   310 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  237 Obj: -4.33E+06 Gap:       NaN
# Iter:   311 I: -9 Tm:      0.52 NLPi:  339 Dpth:   13 Lvs:  236 Obj: -4.33E+06 Gap:       NaN
# Iter:   312 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  238 Obj: -4.33E+06 Gap:       NaN
# Iter:   313 I: -9 Tm:      0.44 NLPi:  340 Dpth:   14 Lvs:  237 Obj: -4.33E+06 Gap:       NaN
# Iter:   314 I:  0 Tm:      0.01 NLPi:    7 Dpth:   14 Lvs:  239 Obj: -4.22E+06 Gap:       NaN
# Iter:   315 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs:  240 Obj: -4.21E+06 Gap:       NaN
# Iter:   316 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  241 Obj: -4.20E+06 Gap:       NaN
# Iter:   317 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  242 Obj: -4.22E+06 Gap:       NaN
# Iter:   318 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  243 Obj: -4.17E+06 Gap:       NaN
# Iter:   319 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  244 Obj: -4.23E+06 Gap:       NaN
# Iter:   320 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  245 Obj: -3.74E+06 Gap:       NaN
# Iter:   321 I: -9 Tm:      0.47 NLPi:  341 Dpth:   10 Lvs:  244 Obj: -4.32E+06 Gap:       NaN
# Iter:   322 I:  0 Tm:      0.01 NLPi:    9 Dpth:   10 Lvs:  246 Obj: -4.32E+06 Gap:       NaN
# Iter:   323 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  247 Obj: -4.32E+06 Gap:       NaN
# Iter:   324 I:  0 Tm:      0.00 NLPi:    6 Dpth:   10 Lvs:  249 Obj: -4.32E+06 Gap:       NaN
# Iter:   325 I: -9 Tm:      0.47 NLPi:  342 Dpth:   11 Lvs:  248 Obj: -4.32E+06 Gap:       NaN
# Iter:   326 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  250 Obj: -4.32E+06 Gap:       NaN
# Iter:   327 I: -9 Tm:      0.52 NLPi:  343 Dpth:   12 Lvs:  249 Obj: -4.32E+06 Gap:       NaN
# Iter:   328 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  251 Obj: -4.32E+06 Gap:       NaN
# Iter:   329 I: -9 Tm:      0.53 NLPi:  344 Dpth:   13 Lvs:  250 Obj: -4.32E+06 Gap:       NaN
# Iter:   330 I:  0 Tm:      0.01 NLPi:    9 Dpth:   13 Lvs:  252 Obj: -4.32E+06 Gap:       NaN
# Iter:   331 I: -9 Tm:      0.51 NLPi:  345 Dpth:   14 Lvs:  251 Obj: -4.32E+06 Gap:       NaN
# Iter:   332 I:  0 Tm:      0.01 NLPi:    6 Dpth:   14 Lvs:  253 Obj: -4.27E+06 Gap:       NaN
# Iter:   333 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs:  254 Obj: -4.07E+06 Gap:       NaN
# Iter:   334 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  255 Obj: -3.93E+06 Gap:       NaN
# Iter:   335 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  256 Obj: -4.22E+06 Gap:       NaN
# Iter:   336 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  257 Obj: -4.17E+06 Gap:       NaN
# Iter:   337 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  258 Obj: -3.96E+06 Gap:       NaN
# Iter:   338 I: -9 Tm:      0.47 NLPi:  346 Dpth:    9 Lvs:  257 Obj: -4.32E+06 Gap:       NaN
# Iter:   339 I:  0 Tm:      0.01 NLPi:    8 Dpth:    9 Lvs:  259 Obj: -4.31E+06 Gap:       NaN
# Iter:   340 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  260 Obj: -4.31E+06 Gap:       NaN
# Iter:   341 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  262 Obj: -4.32E+06 Gap:       NaN
# Iter:   342 I: -9 Tm:      0.45 NLPi:  347 Dpth:   10 Lvs:  261 Obj: -4.32E+06 Gap:       NaN
# Iter:   343 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  263 Obj: -4.32E+06 Gap:       NaN
# Iter:   344 I: -9 Tm:      0.51 NLPi:  348 Dpth:   11 Lvs:  262 Obj: -4.32E+06 Gap:       NaN
# Iter:   345 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  264 Obj: -4.22E+06 Gap:       NaN
# Iter:   346 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  265 Obj: -4.22E+06 Gap:       NaN
# Iter:   347 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  266 Obj: -4.17E+06 Gap:       NaN
# Iter:   348 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  267 Obj: -3.93E+06 Gap:       NaN
# Iter:   349 I: -9 Tm:      0.67 NLPi:  349 Dpth:   11 Lvs:  266 Obj: -4.32E+06 Gap:       NaN
# Iter:   350 I:  0 Tm:      0.01 NLPi:    8 Dpth:   11 Lvs:  268 Obj: -4.42E+06 Gap:       NaN
# Iter:   351 I: -9 Tm:      0.49 NLPi:  350 Dpth:   12 Lvs:  267 Obj: -4.42E+06 Gap:       NaN
# Iter:   352 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  269 Obj: -4.42E+06 Gap:       NaN
# Iter:   353 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  270 Obj: -4.29E+06 Gap:       NaN
# Iter:   354 I: -9 Tm:      0.44 NLPi:  351 Dpth:   13 Lvs:  269 Obj: -4.42E+06 Gap:       NaN
# Iter:   355 I:  0 Tm:      0.01 NLPi:    8 Dpth:   13 Lvs:  271 Obj: -4.19E+06 Gap:       NaN
# Iter:   356 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  272 Obj: -4.31E+06 Gap:       NaN
# Iter:   357 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs:  273 Obj: -4.26E+06 Gap:       NaN
# Iter:   358 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  275 Obj: -4.32E+06 Gap:       NaN
# Iter:   359 I: -9 Tm:      0.49 NLPi:  352 Dpth:   12 Lvs:  274 Obj: -4.32E+06 Gap:       NaN
# Iter:   360 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  276 Obj: -4.32E+06 Gap:       NaN
# Iter:   361 I: -9 Tm:      0.48 NLPi:  353 Dpth:   13 Lvs:  275 Obj: -4.32E+06 Gap:       NaN
# Iter:   362 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  277 Obj: -4.32E+06 Gap:       NaN
# Iter:   363 I: -9 Tm:      0.46 NLPi:  354 Dpth:   14 Lvs:  276 Obj: -4.32E+06 Gap:       NaN
# Iter:   364 I:  0 Tm:      0.01 NLPi:    7 Dpth:   14 Lvs:  278 Obj: -4.20E+06 Gap:       NaN
# Iter:   365 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs:  279 Obj: -4.16E+06 Gap:       NaN
# Iter:   366 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  280 Obj: -4.20E+06 Gap:       NaN
# Iter:   367 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  281 Obj: -4.19E+06 Gap:       NaN
# Iter:   368 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  282 Obj: -4.21E+06 Gap:       NaN
# Iter:   369 I: -9 Tm:      0.42 NLPi:  355 Dpth:    7 Lvs:  281 Obj: -4.32E+06 Gap:       NaN
# Iter:   370 I:  0 Tm:      0.01 NLPi:    9 Dpth:    7 Lvs:  283 Obj: -4.33E+06 Gap:       NaN
# Iter:   371 I: -9 Tm:      0.39 NLPi:  356 Dpth:    8 Lvs:  282 Obj: -4.33E+06 Gap:       NaN
# Iter:   372 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  284 Obj: -4.38E+06 Gap:       NaN
# Iter:   373 I: -9 Tm:      0.43 NLPi:  357 Dpth:    9 Lvs:  283 Obj: -4.38E+06 Gap:       NaN
# Iter:   374 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  285 Obj: -4.38E+06 Gap:       NaN
# Iter:   375 I: -9 Tm:      0.46 NLPi:  358 Dpth:   10 Lvs:  284 Obj: -4.38E+06 Gap:       NaN
# Iter:   376 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  286 Obj: -4.38E+06 Gap:       NaN
# Iter:   377 I: -9 Tm:      0.51 NLPi:  359 Dpth:   11 Lvs:  285 Obj: -4.38E+06 Gap:       NaN
# Iter:   378 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  287 Obj: -4.28E+06 Gap:       NaN
# Iter:   379 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  288 Obj: -4.28E+06 Gap:       NaN
# Iter:   380 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  289 Obj: -4.22E+06 Gap:       NaN
# Iter:   381 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  290 Obj: -4.02E+06 Gap:       NaN
# Iter:   382 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  291 Obj: -4.29E+06 Gap:       NaN
# Iter:   383 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:  292 Obj: -4.33E+06 Gap:       NaN
# Iter:   384 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  294 Obj: -3.97E+06 Gap:       NaN
# Iter:   385 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  295 Obj: -3.97E+06 Gap:       NaN
# Iter:   386 I:  0 Tm:      0.01 NLPi:    8 Dpth:    7 Lvs:  297 Obj: -4.27E+06 Gap:       NaN
# Iter:   387 I:  0 Tm:      0.00 NLPi:    3 Dpth:    7 Lvs:  298 Obj: -4.27E+06 Gap:       NaN
# Iter:   388 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  300 Obj: -4.16E+06 Gap:       NaN
# Iter:   389 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  301 Obj: -4.16E+06 Gap:       NaN
# Iter:   390 I: -9 Tm:      0.51 NLPi:  360 Dpth:   11 Lvs:  300 Obj: -4.32E+06 Gap:       NaN
# Iter:   391 I:  0 Tm:      0.01 NLPi:    8 Dpth:   11 Lvs:  302 Obj: -4.27E+06 Gap:       NaN
# Iter:   392 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs:  303 Obj: -4.27E+06 Gap:       NaN
# Iter:   393 I:  0 Tm:      0.01 NLPi:    6 Dpth:   14 Lvs:  305 Obj: -4.21E+06 Gap:       NaN
# Iter:   394 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs:  306 Obj: -4.19E+06 Gap:       NaN
# Iter:   395 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  308 Obj: -4.31E+06 Gap:       NaN
# Iter:   396 I: -9 Tm:      0.52 NLPi:  361 Dpth:   11 Lvs:  307 Obj: -4.31E+06 Gap:       NaN
# Iter:   397 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  309 Obj: -4.31E+06 Gap:       NaN
# Iter:   398 I: -9 Tm:      0.48 NLPi:  362 Dpth:   12 Lvs:  308 Obj: -4.31E+06 Gap:       NaN
# Iter:   399 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  310 Obj: -4.31E+06 Gap:       NaN
# Iter:   400 I: -9 Tm:      0.51 NLPi:  363 Dpth:   13 Lvs:  309 Obj: -4.31E+06 Gap:       NaN
# Iter:   401 I:  0 Tm:      0.01 NLPi:    6 Dpth:   13 Lvs:  311 Obj: -4.31E+06 Gap:       NaN
# Iter:   402 I: -9 Tm:      0.56 NLPi:  364 Dpth:   14 Lvs:  310 Obj: -4.31E+06 Gap:       NaN
# Iter:   403 I:  0 Tm:      0.01 NLPi:   11 Dpth:   14 Lvs:  312 Obj: -4.26E+06 Gap:       NaN
# Iter:   404 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs:  313 Obj: -4.18E+06 Gap:       NaN
# Iter:   405 I:  0 Tm:      0.00 NLPi:    5 Dpth:   13 Lvs:  314 Obj: -4.06E+06 Gap:       NaN
# Iter:   406 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  315 Obj: -4.20E+06 Gap:       NaN
# Iter:   407 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  316 Obj: -3.92E+06 Gap:       NaN
# Iter:   408 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  317 Obj: -4.15E+06 Gap:       NaN
# Iter:   409 I: -9 Tm:      0.51 NLPi:  365 Dpth:   10 Lvs:  316 Obj: -4.31E+06 Gap:       NaN
# Iter:   410 I:  0 Tm:      0.01 NLPi:    8 Dpth:   10 Lvs:  318 Obj: -4.26E+06 Gap:       NaN
# Iter:   411 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  319 Obj: -4.26E+06 Gap:       NaN
# Iter:   412 I:  0 Tm:      0.00 NLPi:    5 Dpth:   11 Lvs:  321 Obj: -4.31E+06 Gap:       NaN
# Iter:   413 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  322 Obj: -4.21E+06 Gap:       NaN
# Iter:   414 I: -9 Tm:      0.54 NLPi:  366 Dpth:   12 Lvs:  321 Obj: -4.31E+06 Gap:       NaN
# Iter:   415 I: -9 Tm:      1.02 NLPi:  367 Dpth:   12 Lvs:  320 Obj: -4.31E+06 Gap:       NaN
# Iter:   416 I:  0 Tm:      0.00 NLPi:    5 Dpth:   12 Lvs:  321 Obj: -4.03E+06 Gap:       NaN
# Iter:   417 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs:  323 Obj: -4.31E+06 Gap:       NaN
# Iter:   418 I: -9 Tm:      0.44 NLPi:  368 Dpth:   10 Lvs:  322 Obj: -4.31E+06 Gap:       NaN
# Iter:   419 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  324 Obj: -4.21E+06 Gap:       NaN
# Iter:   420 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  325 Obj: -4.21E+06 Gap:       NaN
# Iter:   421 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  326 Obj: -4.20E+06 Gap:       NaN
# Iter:   422 I:  0 Tm:      0.01 NLPi:    6 Dpth:    8 Lvs:  328 Obj: -4.31E+06 Gap:       NaN
# Iter:   423 I: -9 Tm:      0.45 NLPi:  369 Dpth:    9 Lvs:  327 Obj: -4.31E+06 Gap:       NaN
# Iter:   424 I:  0 Tm:      0.01 NLPi:    6 Dpth:    9 Lvs:  329 Obj: -4.31E+06 Gap:       NaN
# Iter:   425 I: -9 Tm:      0.47 NLPi:  370 Dpth:   10 Lvs:  328 Obj: -4.31E+06 Gap:       NaN
# Iter:   426 I:  0 Tm:      0.01 NLPi:    8 Dpth:   10 Lvs:  330 Obj: -4.20E+06 Gap:       NaN
# Iter:   427 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  331 Obj: -4.20E+06 Gap:       NaN
# Iter:   428 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  332 Obj: -4.21E+06 Gap:       NaN
# Iter:   429 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  333 Obj: -4.22E+06 Gap:       NaN
# Iter:   430 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs:  335 Obj: -4.31E+06 Gap:       NaN
# Iter:   431 I: -9 Tm:      0.52 NLPi:  371 Dpth:   11 Lvs:  334 Obj: -4.31E+06 Gap:       NaN
# Iter:   432 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  336 Obj: -4.31E+06 Gap:       NaN
# Iter:   433 I: -9 Tm:      0.52 NLPi:  372 Dpth:   12 Lvs:  335 Obj: -4.31E+06 Gap:       NaN
# Iter:   434 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  337 Obj: -4.20E+06 Gap:       NaN
# Iter:   435 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  338 Obj: -4.20E+06 Gap:       NaN
# Iter:   436 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  339 Obj: -3.91E+06 Gap:       NaN
# Iter:   437 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  340 Obj: -4.21E+06 Gap:       NaN
# Iter:   438 I: -9 Tm:      0.61 NLPi:  373 Dpth:   10 Lvs:  339 Obj: -4.31E+06 Gap:       NaN
# Iter:   439 I:  0 Tm:      0.01 NLPi:    8 Dpth:   10 Lvs:  341 Obj: -4.40E+06 Gap:       NaN
# Iter:   440 I: -9 Tm:      0.55 NLPi:  374 Dpth:   11 Lvs:  340 Obj: -4.40E+06 Gap:       NaN
# Iter:   441 I:  0 Tm:      0.01 NLPi:    9 Dpth:   11 Lvs:  342 Obj: -4.30E+06 Gap:       NaN
# Iter:   442 I:  0 Tm:      0.00 NLPi:    2 Dpth:   11 Lvs:  343 Obj: -4.36E+06 Gap:       NaN
# Iter:   443 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  345 Obj: -4.27E+06 Gap:       NaN
# Iter:   444 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  346 Obj: -4.26E+06 Gap:       NaN
# Iter:   445 I:  0 Tm:      0.00 NLPi:    4 Dpth:   10 Lvs:  347 Obj: -3.88E+06 Gap:       NaN
# Iter:   446 I:  0 Tm:      0.01 NLPi:    6 Dpth:   12 Lvs:  349 Obj: -4.31E+06 Gap:       NaN
# Iter:   447 I: -9 Tm:      0.56 NLPi:  375 Dpth:   13 Lvs:  348 Obj: -4.31E+06 Gap:       NaN
# Iter:   448 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  350 Obj: -4.10E+06 Gap:       NaN
# Iter:   449 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  351 Obj: -4.05E+06 Gap:       NaN
# Iter:   450 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  352 Obj: -4.20E+06 Gap:       NaN
# Iter:   451 I:  0 Tm:      0.01 NLPi:    6 Dpth:    8 Lvs:  354 Obj: -4.31E+06 Gap:       NaN
# Iter:   452 I: -9 Tm:      0.44 NLPi:  376 Dpth:    9 Lvs:  353 Obj: -4.31E+06 Gap:       NaN
# Iter:   453 I:  0 Tm:      0.00 NLPi:    6 Dpth:    9 Lvs:  355 Obj: -4.31E+06 Gap:       NaN
# Iter:   454 I: -9 Tm:      0.50 NLPi:  377 Dpth:   10 Lvs:  354 Obj: -4.31E+06 Gap:       NaN
# Iter:   455 I:  0 Tm:      0.01 NLPi:    7 Dpth:   10 Lvs:  356 Obj: -4.31E+06 Gap:       NaN
# Iter:   456 I: -9 Tm:      0.46 NLPi:  378 Dpth:   11 Lvs:  355 Obj: -4.31E+06 Gap:       NaN
# Iter:   457 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  357 Obj: -4.31E+06 Gap:       NaN
# Iter:   458 I: -9 Tm:      0.51 NLPi:  379 Dpth:   12 Lvs:  356 Obj: -4.31E+06 Gap:       NaN
# Iter:   459 I:  0 Tm:      0.01 NLPi:    8 Dpth:   12 Lvs:  358 Obj: -4.20E+06 Gap:       NaN
# Iter:   460 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  359 Obj: -4.20E+06 Gap:       NaN
# Iter:   461 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs:  360 Obj: -4.18E+06 Gap:       NaN
# Iter:   462 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  361 Obj: -4.15E+06 Gap:       NaN
# Iter:   463 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  362 Obj: -4.21E+06 Gap:       NaN
# Iter:   464 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  363 Obj: -4.22E+06 Gap:       NaN
# Iter:   465 I: -9 Tm:      0.46 NLPi:  380 Dpth:    8 Lvs:  362 Obj: -4.31E+06 Gap:       NaN
# Iter:   466 I:  0 Tm:      0.01 NLPi:    7 Dpth:    8 Lvs:  364 Obj: -4.28E+06 Gap:       NaN
# Iter:   467 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  365 Obj: -4.28E+06 Gap:       NaN
# Iter:   468 I:  0 Tm:      0.01 NLPi:    6 Dpth:    8 Lvs:  367 Obj: -4.31E+06 Gap:       NaN
# Iter:   469 I: -9 Tm:      0.50 NLPi:  381 Dpth:    9 Lvs:  366 Obj: -4.31E+06 Gap:       NaN
# Iter:   470 I:  0 Tm:      0.01 NLPi:    6 Dpth:    9 Lvs:  368 Obj: -4.31E+06 Gap:       NaN
# Iter:   471 I: -9 Tm:      0.44 NLPi:  382 Dpth:   10 Lvs:  367 Obj: -4.31E+06 Gap:       NaN
# Iter:   472 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs:  369 Obj: -4.31E+06 Gap:       NaN
# Iter:   473 I: -9 Tm:      0.48 NLPi:  383 Dpth:   11 Lvs:  368 Obj: -4.31E+06 Gap:       NaN
# Iter:   474 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs:  370 Obj: -4.31E+06 Gap:       NaN
# Iter:   475 I: -9 Tm:      0.50 NLPi:  384 Dpth:   12 Lvs:  369 Obj: -4.31E+06 Gap:       NaN
# Iter:   476 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs:  371 Obj: -4.31E+06 Gap:       NaN
# Iter:   477 I: -9 Tm:      0.55 NLPi:  385 Dpth:   13 Lvs:  370 Obj: -4.31E+06 Gap:       NaN
# Iter:   478 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs:  372 Obj: -4.31E+06 Gap:       NaN
# Iter:   479 I: -9 Tm:      0.48 NLPi:  386 Dpth:   14 Lvs:  371 Obj: -4.31E+06 Gap:       NaN
# Iter:   480 I:  0 Tm:      0.01 NLPi:    7 Dpth:   14 Lvs:  373 Obj: -4.31E+06 Gap:       NaN
# Iter:   481 I: -9 Tm:      0.56 NLPi:  387 Dpth:   15 Lvs:  372 Obj: -4.31E+06 Gap:       NaN
# Iter:   482 I:  0 Tm:      0.01 NLPi:   16 Dpth:   15 Lvs:  374 Obj: -4.31E+06 Gap:       NaN
# Iter:   483 I: -9 Tm:      0.40 NLPi:  388 Dpth:   16 Lvs:  373 Obj: -4.31E+06 Gap:       NaN
# Iter:   484 I:  0 Tm:      0.01 NLPi:   11 Dpth:   16 Lvs:  375 Obj: -3.86E+06 Gap:       NaN
# Iter:   485 I:  0 Tm:      0.00 NLPi:    5 Dpth:   16 Lvs:  376 Obj: -4.03E+06 Gap:       NaN
# Iter:   486 I:  0 Tm:      0.00 NLPi:    5 Dpth:   15 Lvs:  377 Obj: -4.05E+06 Gap:       NaN
# Iter:   487 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs:  378 Obj: -4.18E+06 Gap:       NaN
# Iter:   488 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs:  379 Obj: -4.18E+06 Gap:       NaN
# Iter:   489 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  380 Obj: -4.15E+06 Gap:       NaN
# Iter:   490 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs:  381 Obj: -4.20E+06 Gap:       NaN
# Iter:   491 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs:  382 Obj: -4.21E+06 Gap:       NaN
# Iter:   492 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs:  383 Obj: -3.72E+06 Gap:       NaN
# Iter:   493 I:  0 Tm:      0.00 NLPi:    3 Dpth:    8 Lvs:  384 Obj: -4.22E+06 Gap:       NaN
# Iter:   494 I:  0 Tm:      0.00 NLPi:    5 Dpth:   10 Lvs:  386 Obj: -4.30E+06 Gap:       NaN
# Iter:   495 I: -9 Tm:      0.51 NLPi:  389 Dpth:   11 Lvs:  385 Obj: -4.30E+06 Gap:       NaN
# Iter:   496 I:  0 Tm:      0.01 NLPi:    6 Dpth:   11 Lvs:  387 Obj: -4.30E+06 Gap:       NaN
# Iter:   497 I: -9 Tm:      0.53 NLPi:  390 Dpth:   12 Lvs:  386 Obj: -4.30E+06 Gap:       NaN
# Iter:   498 I:  0 Tm:      0.01 NLPi:    6 Dpth:   12 Lvs:  388 Obj: -4.30E+06 Gap:       NaN
# Iter:   499 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs:  389 Obj: -4.17E+06 Gap:       NaN
# Iter:   500 I:  0 Tm:      0.00 NLPi:    4 Dpth:   11 Lvs:  390 Obj: -4.19E+06 Gap:       NaN
# Iter:   501 I: -9 Tm:      0.52 NLPi:  391 Dpth:   13 Lvs:  389 Obj: -4.30E+06 Gap:       NaN
# ...
# Iter:  2099 I: -9 Tm:      1.09 NLPi:  912 Dpth:   11 Lvs: 1428 Obj: -4.18E+06 Gap:       NaN
# Iter:  2100 I:  0 Tm:      0.00 NLPi:    6 Dpth:   11 Lvs: 1430 Obj: -4.18E+06 Gap:       NaN
# Iter:  2101 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs: 1431 Obj: -4.02E+06 Gap:       NaN
# Iter:  2102 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs: 1432 Obj: -4.07E+06 Gap:       NaN
# Iter:  2103 I: -9 Tm:      1.13 NLPi:  913 Dpth:   12 Lvs: 1431 Obj: -4.18E+06 Gap:       NaN
# Iter:  2104 I:  0 Tm:      0.00 NLPi:    6 Dpth:   12 Lvs: 1433 Obj: -4.18E+06 Gap:       NaN
# Iter:  2105 I: -9 Tm:      1.18 NLPi:  914 Dpth:   13 Lvs: 1432 Obj: -4.18E+06 Gap:       NaN
# Iter:  2106 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs: 1434 Obj: -4.18E+06 Gap:       NaN
# Iter:  2107 I: -9 Tm:      1.17 NLPi:  915 Dpth:   14 Lvs: 1433 Obj: -4.18E+06 Gap:       NaN
# Iter:  2108 I:  0 Tm:      0.01 NLPi:    7 Dpth:   14 Lvs: 1435 Obj: -4.18E+06 Gap:       NaN
# Iter:  2109 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs: 1436 Obj: -4.05E+06 Gap:       NaN
# Iter:  2110 I:  0 Tm:      0.00 NLPi:    3 Dpth:   13 Lvs: 1437 Obj: -4.05E+06 Gap:       NaN
# Iter:  2111 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs: 1438 Obj: -3.43E+06 Gap:       NaN
# Iter:  2112 I: -9 Tm:      1.20 NLPi:  916 Dpth:   15 Lvs: 1437 Obj: -4.18E+06 Gap:       NaN
# Iter:  2113 I:  0 Tm:      0.01 NLPi:    7 Dpth:   15 Lvs: 1439 Obj: -4.18E+06 Gap:       NaN
# Iter:  2114 I: -9 Tm:      1.01 NLPi:  917 Dpth:   16 Lvs: 1438 Obj: -4.18E+06 Gap:       NaN
# Iter:  2115 I:  0 Tm:      0.00 NLPi:    6 Dpth:   16 Lvs: 1440 Obj: -4.18E+06 Gap:       NaN
# Iter:  2116 I:  0 Tm:      0.00 NLPi:    5 Dpth:   16 Lvs: 1441 Obj: -3.92E+06 Gap:       NaN
# Iter:  2117 I: -1 Tm:      0.09 NLPi:   92 Dpth:   17 Lvs: 1440 Obj: -4.18E+06 Gap:       NaN
# Iter:  2118 I:  0 Tm:      0.01 NLPi:    9 Dpth:   17 Lvs: 1442 Obj: -4.11E+06 Gap:       NaN
# Iter:  2119 I:  0 Tm:      0.00 NLPi:    5 Dpth:   17 Lvs: 1443 Obj: -3.82E+06 Gap:       NaN
# Iter:  2120 I:  0 Tm:      0.00 NLPi:    4 Dpth:   15 Lvs: 1444 Obj: -3.78E+06 Gap:       NaN
# Iter:  2121 I:  0 Tm:      0.00 NLPi:    5 Dpth:   17 Lvs: 1446 Obj: -4.11E+06 Gap:       NaN
# Iter:  2122 I:  0 Tm:      0.00 NLPi:    5 Dpth:   17 Lvs: 1447 Obj: -3.92E+06 Gap:       NaN
# Iter:  2123 I:  0 Tm:      0.01 NLPi:    9 Dpth:   14 Lvs: 1449 Obj: -4.07E+06 Gap:       NaN
# Iter:  2124 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs: 1450 Obj: -4.05E+06 Gap:       NaN
# Iter:  2125 I:  0 Tm:      0.00 NLPi:    6 Dpth:   14 Lvs: 1452 Obj: -4.12E+06 Gap:       NaN
# Iter:  2126 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs: 1453 Obj: -3.59E+06 Gap:       NaN
# Iter:  2127 I:  0 Tm:      0.01 NLPi:    7 Dpth:   11 Lvs: 1455 Obj: -4.18E+06 Gap:       NaN
# Iter:  2128 I: -9 Tm:      1.30 NLPi:  918 Dpth:   12 Lvs: 1454 Obj: -4.18E+06 Gap:       NaN
# Iter:  2129 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs: 1456 Obj: -4.18E+06 Gap:       NaN
# Iter:  2130 I: -9 Tm:      1.33 NLPi:  919 Dpth:   13 Lvs: 1455 Obj: -4.18E+06 Gap:       NaN
# Iter:  2131 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs: 1457 Obj: -4.18E+06 Gap:       NaN
# Iter:  2132 I: -9 Tm:      1.41 NLPi:  920 Dpth:   14 Lvs: 1456 Obj: -4.18E+06 Gap:       NaN
# Iter:  2133 I:  0 Tm:      0.01 NLPi:    6 Dpth:   14 Lvs: 1458 Obj: -4.18E+06 Gap:       NaN
# Iter:  2134 I: -9 Tm:      1.34 NLPi:  921 Dpth:   15 Lvs: 1457 Obj: -4.18E+06 Gap:       NaN
# Iter:  2135 I:  0 Tm:      0.01 NLPi:    7 Dpth:   15 Lvs: 1459 Obj: -4.18E+06 Gap:       NaN
# Iter:  2136 I: -9 Tm:      1.49 NLPi:  922 Dpth:   16 Lvs: 1458 Obj: -4.18E+06 Gap:       NaN
# Iter:  2137 I:  0 Tm:      0.01 NLPi:   12 Dpth:   16 Lvs: 1460 Obj: -3.73E+06 Gap:       NaN
# Iter:  2138 I:  0 Tm:      0.00 NLPi:    5 Dpth:   16 Lvs: 1461 Obj: -3.89E+06 Gap:       NaN
# Iter:  2139 I:  0 Tm:      0.00 NLPi:    5 Dpth:   15 Lvs: 1462 Obj: -4.05E+06 Gap:       NaN
# Iter:  2140 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs: 1463 Obj: -3.92E+06 Gap:       NaN
# Iter:  2141 I:  0 Tm:      0.00 NLPi:    4 Dpth:   13 Lvs: 1464 Obj: -3.78E+06 Gap:       NaN
# Iter:  2142 I:  0 Tm:      0.00 NLPi:    4 Dpth:   12 Lvs: 1465 Obj: -4.05E+06 Gap:       NaN
# Iter:  2143 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs: 1466 Obj: -4.07E+06 Gap:       NaN
# Iter:  2144 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs: 1468 Obj: -4.18E+06 Gap:       NaN
# Iter:  2145 I: -9 Tm:      1.25 NLPi:  923 Dpth:   13 Lvs: 1467 Obj: -4.18E+06 Gap:       NaN
# Iter:  2146 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs: 1469 Obj: -4.18E+06 Gap:       NaN
# Iter:  2147 I: -9 Tm:      1.34 NLPi:  924 Dpth:   14 Lvs: 1468 Obj: -4.18E+06 Gap:       NaN
# Iter:  2148 I:  0 Tm:      0.01 NLPi:    7 Dpth:   14 Lvs: 1470 Obj: -4.18E+06 Gap:       NaN
# Iter:  2149 I: -9 Tm:      1.54 NLPi:  925 Dpth:   15 Lvs: 1469 Obj: -4.18E+06 Gap:       NaN
# Iter:  2150 I:  0 Tm:      0.01 NLPi:    7 Dpth:   15 Lvs: 1471 Obj: -4.18E+06 Gap:       NaN
# Iter:  2151 I: -9 Tm:      1.53 NLPi:  926 Dpth:   16 Lvs: 1470 Obj: -4.18E+06 Gap:       NaN
# Iter:  2152 I:  0 Tm:      0.00 NLPi:    6 Dpth:   16 Lvs: 1472 Obj: -4.18E+06 Gap:       NaN
# Iter:  2153 I: -9 Tm:      0.96 NLPi:  927 Dpth:   17 Lvs: 1471 Obj: -4.18E+06 Gap:       NaN
# Iter:  2154 I:  0 Tm:      0.00 NLPi:    6 Dpth:   17 Lvs: 1473 Obj: -4.09E+06 Gap:       NaN
# Iter:  2155 I:  0 Tm:      0.00 NLPi:    5 Dpth:   17 Lvs: 1474 Obj: -3.82E+06 Gap:       NaN
# Iter:  2156 I:  0 Tm:      0.00 NLPi:    5 Dpth:   16 Lvs: 1475 Obj: -3.92E+06 Gap:       NaN
# Iter:  2157 I:  0 Tm:      0.00 NLPi:    4 Dpth:   15 Lvs: 1476 Obj: -3.89E+06 Gap:       NaN
# Iter:  2158 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs: 1477 Obj: -4.05E+06 Gap:       NaN
# Iter:  2159 I:  0 Tm:      0.00 NLPi:    3 Dpth:   13 Lvs: 1478 Obj: -4.07E+06 Gap:       NaN
# Iter:  2160 I:  0 Tm:      0.00 NLPi:    3 Dpth:   12 Lvs: 1479 Obj: -3.78E+06 Gap:       NaN
# Iter:  2161 I:  0 Tm:      0.00 NLPi:    6 Dpth:   14 Lvs: 1481 Obj: -4.18E+06 Gap:       NaN
# Iter:  2162 I: -9 Tm:      1.46 NLPi:  928 Dpth:   15 Lvs: 1480 Obj: -4.18E+06 Gap:       NaN
# Iter:  2163 I:  0 Tm:      0.00 NLPi:    6 Dpth:   15 Lvs: 1482 Obj: -4.18E+06 Gap:       NaN
# Iter:  2164 I: -9 Tm:      2.59 NLPi:  929 Dpth:   16 Lvs: 1481 Obj: -4.18E+06 Gap:       NaN
# Iter:  2165 I:  0 Tm:      0.00 NLPi:    6 Dpth:   16 Lvs: 1483 Obj: -4.18E+06 Gap:       NaN
# Iter:  2166 I:  0 Tm:      0.00 NLPi:    5 Dpth:   16 Lvs: 1484 Obj: -3.92E+06 Gap:       NaN
# Iter:  2167 I:  0 Tm:      0.00 NLPi:    4 Dpth:   15 Lvs: 1485 Obj: -3.89E+06 Gap:       NaN
# Iter:  2168 I: -1 Tm:      0.01 NLPi:   11 Dpth:   17 Lvs: 1484 Obj: -4.18E+06 Gap:       NaN
# Iter:  2169 I: -9 Tm:      2.40 NLPi:  930 Dpth:   17 Lvs: 1483 Obj: -4.18E+06 Gap:       NaN
# Iter:  2170 I:  0 Tm:      0.00 NLPi:    5 Dpth:   17 Lvs: 1484 Obj: -3.82E+06 Gap:       NaN
# Iter:  2171 I:  0 Tm:      0.00 NLPi:    4 Dpth:   14 Lvs: 1485 Obj: -4.05E+06 Gap:       NaN
# Iter:  2172 I: -9 Tm:      0.90 NLPi:  931 Dpth:   14 Lvs: 1484 Obj: -4.18E+06 Gap:       NaN
# Iter:  2173 I: -9 Tm:      2.48 NLPi:  932 Dpth:   14 Lvs: 1483 Obj: -4.18E+06 Gap:       NaN
# Iter:  2174 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs: 1484 Obj: -3.61E+06 Gap:       NaN
# Iter:  2175 I:  0 Tm:      0.01 NLPi:    8 Dpth:   14 Lvs: 1486 Obj: -4.18E+06 Gap:       NaN
# Iter:  2176 I: -9 Tm:      1.46 NLPi:  933 Dpth:   15 Lvs: 1485 Obj: -4.18E+06 Gap:       NaN
# Iter:  2177 I: -9 Tm:      2.49 NLPi:  934 Dpth:   15 Lvs: 1484 Obj: -4.18E+06 Gap:       NaN
# Iter:  2178 I:  0 Tm:      0.00 NLPi:    5 Dpth:   15 Lvs: 1485 Obj: -3.89E+06 Gap:       NaN
# Iter:  2179 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs: 1486 Obj: -4.05E+06 Gap:       NaN
# Iter:  2180 I:  0 Tm:      0.00 NLPi:    6 Dpth:   14 Lvs: 1488 Obj: -4.18E+06 Gap:       NaN
# Iter:  2181 I: -9 Tm:      1.35 NLPi:  935 Dpth:   15 Lvs: 1487 Obj: -4.18E+06 Gap:       NaN
# Iter:  2182 I: -9 Tm:      2.47 NLPi:  936 Dpth:   15 Lvs: 1486 Obj: -4.18E+06 Gap:       NaN
# Iter:  2183 I:  0 Tm:      0.00 NLPi:    5 Dpth:   15 Lvs: 1487 Obj: -3.78E+06 Gap:       NaN
# Iter:  2184 I:  0 Tm:      0.00 NLPi:    5 Dpth:   14 Lvs: 1488 Obj: -4.02E+06 Gap:       NaN
# Iter:  2185 I: -1 Tm:      0.38 NLPi:  422 Dpth:   15 Lvs: 1487 Obj: -4.17E+06 Gap:       NaN
# Iter:  2186 I: -9 Tm:      2.51 NLPi:  937 Dpth:   15 Lvs: 1486 Obj: -4.17E+06 Gap:       NaN
# Iter:  2187 I:  0 Tm:      0.00 NLPi:    5 Dpth:   15 Lvs: 1487 Obj: -4.00E+06 Gap:       NaN
# Iter:  2188 I:  0 Tm:      0.01 NLPi:    7 Dpth:    9 Lvs: 1489 Obj: -4.17E+06 Gap:       NaN
# Iter:  2189 I: -9 Tm:      1.04 NLPi:  938 Dpth:   10 Lvs: 1488 Obj: -4.17E+06 Gap:       NaN
# Iter:  2190 I:  0 Tm:      0.01 NLPi:    6 Dpth:   10 Lvs: 1490 Obj: -4.17E+06 Gap:       NaN
# Iter:  2191 I:  0 Tm:      0.00 NLPi:    3 Dpth:   10 Lvs: 1491 Obj: -4.07E+06 Gap:       NaN
# Iter:  2192 I:  0 Tm:      0.00 NLPi:    3 Dpth:    9 Lvs: 1492 Obj: -4.07E+06 Gap:       NaN
# Iter:  2193 I: -9 Tm:      1.12 NLPi:  939 Dpth:   11 Lvs: 1491 Obj: -4.17E+06 Gap:       NaN
# Iter:  2194 I:  0 Tm:      0.00 NLPi:    6 Dpth:   11 Lvs: 1493 Obj: -4.17E+06 Gap:       NaN
# Iter:  2195 I: -9 Tm:      1.10 NLPi:  940 Dpth:   12 Lvs: 1492 Obj: -4.17E+06 Gap:       NaN
# Iter:  2196 I:  0 Tm:      0.01 NLPi:    7 Dpth:   12 Lvs: 1494 Obj: -4.17E+06 Gap:       NaN
# Iter:  2197 I:  0 Tm:      0.00 NLPi:    3 Dpth:   12 Lvs: 1495 Obj: -4.02E+06 Gap:       NaN
# Iter:  2198 I:  0 Tm:      0.00 NLPi:    3 Dpth:   11 Lvs: 1496 Obj: -3.82E+06 Gap:       NaN
# Iter:  2199 I: -9 Tm:      1.15 NLPi:  941 Dpth:   13 Lvs: 1495 Obj: -4.17E+06 Gap:       NaN
# Iter:  2200 I:  0 Tm:      0.01 NLPi:    7 Dpth:   13 Lvs: 1497 Obj: -4.17E+06 Gap:       NaN
# Iter:  2201 I: -9 Tm:      1.21 NLPi:  942 Dpth:   14 Lvs: 1496 Obj: -4.17E+06 Gap:       NaN
# Iter:  2202 I:  0 Tm:      0.01 NLPi:    7 Dpth:   14 Lvs: 1498 Obj: -4.17E+06 Gap:       NaN
# Iter:  2203 I: -9 Tm:      1.28 NLPi:  943 Dpth:   15 Lvs: 1497 Obj: -4.17E+06 Gap:       NaN
# Iter:  2204 I:  0 Tm:      0.00 NLPi:    6 Dpth:   15 Lvs: 1499 Obj: -4.17E+06 Gap:       NaN
# Iter:  2205 I: -9 Tm:      1.00 NLPi:  944 Dpth:   16 Lvs: 1498 Obj: -4.17E+06 Gap:       NaN
# Iter:  2206 I:  0 Tm:      0.00 NLPi:    6 Dpth:   16 Lvs: 1500 Obj: -4.17E+06 Gap:       NaN
# Iter:  2207 I: -9 Tm:      0.93 NLPi:  945 Dpth:   17 Lvs: 1499 Obj: -4.17E+06 Gap:       NaN
# Iter:  2208 I:  0 Tm:      0.01 NLPi:    7 Dpth:   17 Lvs: 1501 Obj: -4.17E+06 Gap:       NaN
# Iter:  2209 I: -9 Tm:      0.89 NLPi:  946 Dpth:   18 Lvs: 1500 Obj: -4.17E+06 Gap:       NaN
# Iter:  2210 I:  0 Tm:      0.00 NLPi:    6 Dpth:   18 Lvs: 1502 Obj: -4.17E+06 Gap:       NaN
# Iter:  2211 I:  0 Tm:      0.00 NLPi:    4 Dpth:   18 Lvs: 1503 Obj: -3.81E+06 Gap:       NaN
# Iter:  2212 I:  0 Tm:      0.00 NLPi:    4 Dpth:   17 Lvs: 1504 Obj: -3.89E+06 Gap:       NaN
# Iter:  2213 I:  0 Tm:      0.00 NLPi:    4 Dpth:   16 Lvs: 1505 Obj: -3.92E+06 Gap:       NaN
# Iter:  2214 I:  0 Tm:      0.00 NLPi:    5 Dpth:   15 Lvs: 1506 Obj: -3.31E+06 Gap:       NaN
# Iter:  2215 I:  0 Tm:      0.00 NLPi:    3 Dpth:   14 Lvs: 1507 Obj: -4.05E+06 Gap:       NaN
# Iter:  2216 I:  0 Tm:      0.00 NLPi:    3 Dpth:   13 Lvs: 1508 Obj: -4.04E+06 Gap:       NaN
# Iter:  2217 I: -1 Tm:      0.82 NLPi:  817 Dpth:   19 Lvs: 1507 Obj: -4.17E+06 Gap:       NaN
# --Integer Solution:  -2.96E+06 Lowest Leaf:  -4.17E+06 Gap:   3.39E-01
# Iter:  2218 I:  0 Tm:      0.01 NLPi:   11 Dpth:   19 Lvs: 1506 Obj: -2.96E+06 Gap:  3.39E-01
#  Warning: best integer solution returned after maximum MINLP iterations
#  Adjust minlp_max_iter_with_int_sol          500  in apopt.opt to change limit
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :    677.799700000003      sec
#  Objective      :   -2964898.27357489
#  Successful solution
#  ---------------------------------------------------
#
#
#
#  OPTIMIZATION RESULTS: ITEM-LEVEL OVERVIEW
# ╒══════════════════════════════════╤══════════════╤═══════════════╤════════════╤═══════════╕
# │ Product Name                     │ Selected     │ Discount %    │ Revenue    │ Margin    │
# ╞══════════════════════════════════╪══════════════╪═══════════════╪════════════╪═══════════╡
# │ Bread                            │ Selected     │ 35.0%         │ $805.31    │ $688.77   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 4 Eggs + 4 Cereal      │ Selected     │ 35.0%         │ $659.38    │ $405.77   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 2 Cheese + 2 Cereal    │ Selected     │ 35.0%         │ $194.67    │ $119.8    │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 3 Butter + 4 Yogurt    │ Selected     │ 35.0%         │ $750.86    │ $462.07   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 4 Butter + 1 Bread     │ Not Selected │ 0.0%          │ $71.64     │ $53.73    │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 5 Juice + 5 Milk       │ Selected     │ 35.0%         │ $622.42    │ $383.03   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 3 Cereal + 2 Milk      │ Not Selected │ 0.0%          │ $503.16    │ $377.37   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 3 Yogurt + 3 Butter    │ Not Selected │ 0.0%          │ $292.68    │ $219.51   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 5 Vegetables + 2 Fruit │ Not Selected │ 0.0%          │ $214.77    │ $161.08   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 1 Butter + 1 Eggs      │ Not Selected │ 0.0%          │ $383.0     │ $287.25   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Bundle of 2 Fruit + 1 Butter     │ Not Selected │ 0.0%          │ $254.46    │ $190.84   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Butter                           │ Selected     │ 35.0%         │ $1149.91   │ $733.17   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Cereal                           │ Selected     │ 35.0%         │ $1020.75   │ $610.3    │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Cheese                           │ Selected     │ 35.0%         │ $454.06    │ $183.58   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Eggs                             │ Selected     │ 35.0%         │ $1898.75   │ $1471.81  │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Fruit                            │ Selected     │ 8.24%         │ $1173.22   │ $477.17   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Juice                            │ Selected     │ 35.0%         │ $1253.87   │ $911.32   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Milk                             │ Not Selected │ 0.0%          │ $459.19    │ $279.15   │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Promo: Vegetables                │ Not Selected │ 0.0%          │ $1274.89   │ $1174.99  │
# ├──────────────────────────────────┼──────────────┼───────────────┼────────────┼───────────┤
# │ Promo: Yogurt                    │ Selected     │ 35.0%         │ $1206.38   │ $809.3    │
# ╘══════════════════════════════════╧══════════════╧═══════════════╧════════════╧═══════════╛
#
#  Summary Metrics:
#  Total Selected Items: 12
#  Total Revenue: $14643.36
#  Total Margin: $10000.0

# %% [markdown]
# ## MILP

# %%
from gekko import GEKKO
import numpy as np

def Solve_MILP_Phase2(
    Phase1_Selection_delta_star,  # Binary selection vector from Phase 1
    Phase1_Discounts_d_star,      # Discount percentages from Phase 1
    DemandForecast_S0,            # Base demand forecast for each item
    PriceElasticity_PE,           # Price elasticity for each item
    DemandSubstitution_S_matrix,  # Substitution effect matrix
    P_reg,                        # Regular prices
    C,                            # Unit costs
    P0,                           # Reference prices
    Targets,                      # Revenue and margin targets
    TotalBudget,                  # Overall budget constraint
    Weights,                      # Weights for revenue and margin in objective
    PenaltyWeights,              # Weights for penalty variables
    BusinessRules,                # Pricing bounds and business constraints
    SolverOptions                 # Options for Gekko solver
):
    """
    Solve the Phase 2 MILP: Linear Perturbation & Demand Substitution
    """

    n = len(P_reg)  # Number of items

    # --- Step 3.1: Compute optimized prices from Phase 1 ---
    P_star = P_reg * (1 - Phase1_Discounts_d_star)

    # --- Step 3.2: Compute demand S*_i using only price elasticity (no substitution yet) ---
    S_star = np.zeros(n)
    for i in range(n):
        if Phase1_Selection_delta_star[i] == 1:
            S_star[i] = DemandForecast_S0[i] * (P_star[i] / P0[i]) ** PriceElasticity_PE[i]
        else:
            S_star[i] = 0

    # --- Step 3.3: Compute derivatives of demand w.r.t. price at P*_i ---
    D = np.zeros(n)
    for i in range(n):
        if Phase1_Selection_delta_star[i] == 1:
            D[i] = PriceElasticity_PE[i] * (S_star[i] / P_star[i])
        else:
            D[i] = 0

    # --- Initialize MILP Model ---
    m = GEKKO(remote=False)
    m.options.SOLVER = 1  # APOPT MILP solver
    m.options.IMODE = 3   # Steady state optimization

    # --- Decision Variables: ΔP_i (Price perturbations), only for selected items ---
    DeltaP = [m.Var(value=0, lb=BusinessRules['MinPriceChange'][i], ub=BusinessRules['MaxPriceChange'][i]) 
              if Phase1_Selection_delta_star[i]==1 else m.Param(0) for i in range(n)]

    # --- Penalty variables for unmet revenue and margin targets ---
    z_R = m.Var(lb=0)
    z_M = m.Var(lb=0)

    # --- Step 3.4: Linearized demand with substitution effects ---
    S2 = [m.Intermediate(
            S_star[i] +
            D[i] * DeltaP[i] +
            m.sum([DemandSubstitution_S_matrix[i][j] * D[j] * DeltaP[j] for j in range(n) 
                   if (j != i and Phase1_Selection_delta_star[j] == 1)])
        ) if Phase1_Selection_delta_star[i]==1 else m.Param(0) for i in range(n)]

    # --- Step 3.4: Compute linearized revenue and margin ---
    r2 = [m.Intermediate(
            P_star[i]*S_star[i] + 
            P_star[i]*(D[i]*DeltaP[i] + m.sum([DemandSubstitution_S_matrix[i][j]*D[j]*DeltaP[j] 
                                               for j in range(n) if (j != i and Phase1_Selection_delta_star[j]==1)])) + 
            DeltaP[i]*S_star[i]
        ) if Phase1_Selection_delta_star[i]==1 else m.Param(0) for i in range(n)]

    m2 = [m.Intermediate(
            (P_star[i] - C[i])*S_star[i] +
            (P_star[i] - C[i])*(D[i]*DeltaP[i] + m.sum([DemandSubstitution_S_matrix[i][j]*D[j]*DeltaP[j] 
                                                       for j in range(n) if (j != i and Phase1_Selection_delta_star[j]==1)])) +
            DeltaP[i]*S_star[i]
        ) if Phase1_Selection_delta_star[i]==1 else m.Param(0) for i in range(n)]

    # --- Step 3.5: Define Objective Function ---
    w1 = Weights['Revenue']
    w2 = Weights['Margin']
    w3 = PenaltyWeights['RevenuePenalty']
    w4 = PenaltyWeights['MarginPenalty']

    # Maximize revenue and margin while penalizing deviations from targets
    obj = w1 * m.sum(r2) + w2 * m.sum(m2) - w3 * z_R - w4 * z_M
    m.Obj(-obj)  # GEKKO minimizes, so we use negative

    # --- Constraints: Ensure revenue and margin meet targets (with slack) ---
    m.Equation(m.sum(r2) + z_R >= Targets['RevenueTarget'])
    m.Equation(m.sum(m2) + z_M >= Targets['MarginTarget'])

    # --- Budget Constraint: Ensure adjusted prices respect the total budget ---
    BudgetUsed = m.sum([(P_star[i] + DeltaP[i]) * S2[i] for i in range(n) if Phase1_Selection_delta_star[i]==1])
    m.Equation(BudgetUsed <= TotalBudget)

    # --- Solve MILP ---
    m.solve(disp=SolverOptions.get('disp', True))

    # --- Step 3.6: Extract optimal price perturbations ---
    OptimalPerturbations_DeltaP = np.array([
        DeltaP[i].value[0] if Phase1_Selection_delta_star[i]==1 else 0 for i in range(n)
    ])

    # --- Step 3.7: Compute Final Prices and Discounts ---
    FinalPrices = {}
    FinalDiscounts = {}
    Final_Selection_delta = Phase1_Selection_delta_star.copy()

    for i in range(n):
        if Final_Selection_delta[i] == 1:
            price = P_star[i] + OptimalPerturbations_DeltaP[i]
            # Clamp price to allowed discount range
            MinP = P_reg[i] * (1 - BusinessRules['MaxDiscount'][i])
            MaxP = P_reg[i] * (1 - BusinessRules['MinDiscount'][i])
            price = min(max(price, MinP), MaxP)
            FinalPrices[i] = price
            FinalDiscounts[i] = 1 - price / P_reg[i]
        else:
            FinalPrices[i] = P_reg[i]
            FinalDiscounts[i] = 0

    # --- Final Key Performance Indicators (KPIs) ---
    Final_KPIs = {
        'Final_Revenue': sum([FinalPrices[i]*S2[i].value[0] for i in range(n) if Final_Selection_delta[i]==1]),
        'Final_Margin': sum([(FinalPrices[i]-C[i])*S2[i].value[0] for i in range(n) if Final_Selection_delta[i]==1]),
        'Final_Sales': sum([S2[i].value[0] for i in range(n) if Final_Selection_delta[i]==1]),
        'Final_BudgetUsed': BudgetUsed.value[0]
    }

    return Final_Selection_delta, FinalDiscounts, Final_KPIs

# %%
import pandas as pd

def print_product_KPIs(Final_Selection_delta, FinalDiscounts, FinalPrices, S2, C, P_reg):
   """
    Prints a tabular summary of key KPIs for each selected product.

    Parameters:
    - Final_Selection_delta: binary list indicating selected products (1 if selected)
    - FinalDiscounts: dictionary of final discount values for each product
    - FinalPrices: dictionary of final price values for each product
    - S2: list of GEKKO Intermediates (expected sales after optimization)
    - C: list of cost values for each product
    - P_reg: list of original (regular) prices for each product
    """
    data = []

    for i in range(len(Final_Selection_delta)):
        if Final_Selection_delta[i] == 1:
            final_price = FinalPrices[i]
            final_discount = FinalDiscounts[i]
            final_sales = S2[i].value[0]
            final_revenue = final_price * final_sales
            final_margin = (final_price - C[i]) * final_sales
            original_price = P_reg[i]

            data.append({
                'Product ID': i,
                'Original Price': round(original_price, 2),
                'Final Price': round(final_price, 2),
                'Discount (%)': round(final_discount * 100, 2),
                'Expected Sales': round(final_sales, 2),  # Extract predicted sales from GEKKO variable
                'Expected Revenue': round(final_revenue, 2),
                'Expected Margin': round(final_margin, 2)
            })

    df = pd.DataFrame(data)
    print("\nKey Performance Indicators for Selected Products:\n")
    print(df.to_string(index=False))
    
    return Final_Selection_delta, FinalDiscounts, FinalPrices, S2, Final_KPIs



Final_Selection_delta, FinalDiscounts, Final_KPIs = Solve_MILP_Phase2(...)
print_product_KPIs(Final_Selection_delta, FinalDiscounts, FinalPrices, S2, C, P_reg)
